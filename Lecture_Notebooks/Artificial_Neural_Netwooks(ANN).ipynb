# %% [markdown]
#  # Artificial Neural Networks (ANN)
#
#
#
# Instructor: Amna Mazen

# %% [markdown]
# ## Import libraries

# %%
# !pip install mglearn
# Out:
# Collecting mglearn
#   Downloading mglearn-0.2.0-py2.py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mglearn) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mglearn) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from mglearn) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from mglearn) (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from mglearn) (11.3.0)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from mglearn) (0.12.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from mglearn) (2.37.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from mglearn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mglearn) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mglearn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mglearn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mglearn) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mglearn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mglearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->mglearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->mglearn) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mglearn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mglearn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mglearn) (1.17.0)
# Downloading mglearn-0.2.0-py2.py3-none-any.whl (581 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: mglearn
# Successfully installed mglearn-0.2.0

# %%
import mglearn

import glob
import copy
import os, sys
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.datasets import make_classification, make_moons, make_circles


from keras.optimizers import SGD


from datetime import datetime
from matplotlib.colors import ListedColormap
from sklearn.datasets import make_classification, make_moons, make_circles
from sklearn.metrics import confusion_matrix, classification_report, mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Activation
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
#from keras.utils.np_utils import to_categorical

# %% [markdown]
# ## Helpful Customized Functions

# %%
def plot_data(X, y, figsize=None):
    if not figsize:
        figsize = (8, 6)
    plt.figure(figsize=figsize)
    plt.plot(X[y==0, 0], X[y==0, 1], 'or', alpha=0.5, label=0)
    plt.plot(X[y==1, 0], X[y==1, 1], 'ob', alpha=0.5, label=1)
    plt.xlim((min(X[:, 0])-0.1, max(X[:, 0])+0.1))
    plt.ylim((min(X[:, 1])-0.1, max(X[:, 1])+0.1))
    plt.legend()

def plot_loss_accuracy(history):
    historydf = pd.DataFrame(history.history, index=history.epoch)
    plt.figure(figsize=(8, 6))
    historydf.plot(ylim=(0, max(1, historydf.values.max())))
    loss = history.history['loss'][-1]
    acc = history.history['accuracy'][-1]
    plt.title('Loss: %.3f, Accuracy: %.3f' % (loss, acc))


def plot_decision_boundary(func, X, y, figsize=(9, 6)):
    amin, bmin = X.min(axis=0) - 0.1
    amax, bmax = X.max(axis=0) + 0.1
    hticks = np.linspace(amin, amax, 101)
    vticks = np.linspace(bmin, bmax, 101)

    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb.ravel()]
    c = func(ab)
    cc = c.reshape(aa.shape)

    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])

    fig, ax = plt.subplots(figsize=figsize)
    contour = plt.contourf(aa, bb, cc, cmap=cm, alpha=0.8)

    ax_c = fig.colorbar(contour)
    ax_c.set_label("$P(y = 1)$")
    ax_c.set_ticks([0, 0.25, 0.5, 0.75, 1])

    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cm_bright)
    plt.xlim(amin, amax)
    plt.ylim(bmin, bmax)

def plot_confusion_matrix(model, X, y):
    y_pred = model.predict(X, verbose=0)>0.5
    plt.figure(figsize=(8, 6))
    sns.heatmap(pd.DataFrame(confusion_matrix(y, y_pred)), annot=True, fmt='d', cmap='YlGnBu', alpha=0.8, vmin=0)

# %% [markdown]
# ## Introduction to neural networks

# %% [markdown]
# - Very popular these days under the name **deep learning**.
# - Neural networks apply a sequence of transformations on your input data.
# - They can be viewed a generalization of linear models where we apply a series of transformations.
# - Here is graphical representation of a logistic regression model.
#     - We have 4 features: x[0], x[1], x[2], x[3]

# %%
mglearn.plots.plot_logistic_regression_graph()

# %% [markdown]
# - Below we are adding one "layer" of transformations in between features and the target.
# - We are repeating the the process of computing the weighted sum multiple times.
# - The **hidden units** (e.g., h[1], h[2], ...) represent the intermediate processing steps.

# %%
mglearn.plots.plot_single_hidden_layer_graph()

# %% [markdown]
# - Now we are adding one more layer of transformations.

# %%
mglearn.plots.plot_two_hidden_layer_graph()

# %% [markdown]
# - At a very high level you can also think of them as `Pipelines` in `sklearn`.
# - A neural network is a model that's sort of like its own pipeline
#   - It involves a series of transformations ("layers") internally.
#   - The output is the prediction.

# %% [markdown]
# - To make them really powerful compared to the linear models, we apply a non-linear function to the weighted sum for each hidden node.

# %% [markdown]
# ## Logistic Regression

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_redundant=0,
                           n_informative=2, random_state=7, n_clusters_per_class=1)
plot_data(X, y)

# %%
lr = LogisticRegression()
lr.fit(X, y)
# Out:
# LogisticRegression()

# %%
print('LR coefficients:', lr.coef_)
print('LR intercept:', lr.intercept_)

plot_data(X, y)

limits = np.array([-2, 2])
boundary = -(lr.coef_[0][0] * limits + lr.intercept_[0]) / lr.coef_[0][1]
plt.plot(limits, boundary, "g-", linewidth=2)
# Out:
# LR coefficients: [[-4.0747209   2.07498216]]
# LR intercept: [-0.26598602]

# %%
## Our first NN model
model = Sequential()
model.add(Dense(units=1, input_shape=(2,), activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Adam (Adaptive Moment Estimation) optimizer is used to adjust learning rates during training.
#It works well with large datasets and complex models because it uses memory efficiently and adapts the learning rate for each parameter automatically.

history = model.fit(x=X, y=y, verbose=1, epochs=75) #The verbose parameter controls how much output you see while your model is training.
# verbose=0  Silent mode – No output at all.
# verbose=1 (Progress bar) – Shows a nice progress bar for each epoch with metrics.
# verbose=2 (One line per epoch) – Prints just one line of summary per epoch (less detailed).
# Out:
# Epoch 1/75
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1790 - loss: 1.0097
# Epoch 2/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1880 - loss: 0.9694
# Epoch 3/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2020 - loss: 0.9306
# Epoch 4/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2170 - loss: 0.8932
# Epoch 5/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2640 - loss: 0.8573
# Epoch 6/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3230 - loss: 0.8228
# Epoch 7/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4040 - loss: 0.7894
# Epoch 8/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5000 - loss: 0.7575
# Epoch 9/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5800 - loss: 0.7269
# Epoch 10/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6310 - loss: 0.6975
# Epoch 11/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6810 - loss: 0.6694
# Epoch 12/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7170 - loss: 0.6424
# Epoch 13/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7540 - loss: 0.6166
# Epoch 14/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7830 - loss: 0.5920
# Epoch 15/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8060 - loss: 0.5682
# Epoch 16/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8260 - loss: 0.5459
# Epoch 17/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5244
# Epoch 18/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.5040
# Epoch 19/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8760 - loss: 0.4844
# Epoch 20/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8950 - loss: 0.4658
# Epoch 21/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9040 - loss: 0.4480
# Epoch 22/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9210 - loss: 0.4311
# Epoch 23/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9310 - loss: 0.4151
# Epoch 24/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9390 - loss: 0.3998
# Epoch 25/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9480 - loss: 0.3851
# Epoch 26/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9520 - loss: 0.3711
# Epoch 27/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9570 - loss: 0.3579
# Epoch 28/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9650 - loss: 0.3452
# Epoch 29/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9690 - loss: 0.3331
# Epoch 30/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9730 - loss: 0.3218
# Epoch 31/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.3108
# Epoch 32/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9800 - loss: 0.3004
# Epoch 33/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.2905
# Epoch 34/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.2811
# Epoch 35/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9920 - loss: 0.2721
# Epoch 36/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9930 - loss: 0.2634
# Epoch 37/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9960 - loss: 0.2553
# Epoch 38/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.2474
# Epoch 39/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.2399
# Epoch 40/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.2328
# Epoch 41/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.2259
# Epoch 42/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9980 - loss: 0.2193
# Epoch 43/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9980 - loss: 0.2130
# Epoch 44/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.2069
# Epoch 45/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.2012
# Epoch 46/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.1956
# Epoch 47/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.1903
# Epoch 48/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1853
# Epoch 49/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1804
# Epoch 50/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1757
# Epoch 51/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1712
# Epoch 52/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1668
# Epoch 53/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1627
# Epoch 54/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1587
# Epoch 55/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1548
# Epoch 56/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1511
# Epoch 57/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1475
# Epoch 58/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1440
# Epoch 59/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1407
# Epoch 60/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1374
# Epoch 61/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1343
# Epoch 62/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1313
# Epoch 63/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1284
# Epoch 64/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1256
# Epoch 65/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1229
# Epoch 66/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1203
# Epoch 67/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1178
# Epoch 68/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1153
# Epoch 69/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1129
# Epoch 70/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1106
# Epoch 71/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1084
# Epoch 72/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1062
# Epoch 73/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1041
# Epoch 74/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1020
# Epoch 75/75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1001

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_loss_accuracy(history)

# %%
plot_decision_boundary(lambda x: model.predict(x), X, y)
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_pred = model.predict(X, verbose=0)>0.5

print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       501
#            1       1.00      1.00      1.00       499
#
#     accuracy                           1.00      1000
#    macro avg       1.00      1.00      1.00      1000
# weighted avg       1.00      1.00      1.00      1000

# %%
plot_confusion_matrix(model, X, y)

# %% [markdown]
# ### Complex data - moons
# The previous dataset was linearly separable, so it was trivial for our logistic regression model to separate the classes. Here is a more complex dataset which isn't linearly separable. The simple logistic regression model won't be able to distinguish between the classes.

# %%
X, y = make_moons(n_samples=1000, noise=0.05, random_state=0)
plot_data(X, y)

# %% [markdown]
# We're building the another logistic regression model with the same parameters as we did before.

# %%
model = Sequential()
model.add(Dense(1, input_shape=(2,), activation='sigmoid'))

model.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
# Adam (Adaptive Moment Estimation) optimizer is used to adjust learning rates during training.
#It works well with large datasets and complex models because it uses memory efficiently and adapts the learning rate for each parameter automatically.

history = model.fit(X, y, verbose=0, epochs=100) #verbose=0 means Silent mode – No output at all.
plot_loss_accuracy(history)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
plot_decision_boundary(lambda x: model.predict(x), X, y)
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step

# %% [markdown]
# Precision of the model is 86%. It looks good on paper but we should be able to get 100% with a more complex model. You can imagine a curved decision boundary that will separate out the classes, and a complex model should be able to approximate that.

# %%
y_pred = model.predict(X, verbose=0)>0.5
print(classification_report(y, y_pred))
plot_confusion_matrix(model, X, y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       500
#            1       0.87      0.87      0.87       500
#
#     accuracy                           0.87      1000
#    macro avg       0.87      0.87      0.87      1000
# weighted avg       0.87      0.87      0.87      1000

# %% [markdown]
# ### Complex Data - Circles
# Let's look at one final example where the liner model will fail.

# %%
X, y = make_circles(n_samples=1000, noise=0.05, factor=0.3, random_state=0)
plot_data(X, y)

# %% [markdown]
# Building the model with same parameters.

# %%
model = Sequential()
model.add(Dense(1, input_shape=(2,), activation='sigmoid'))

model.compile('adam', 'binary_crossentropy', metrics=['accuracy'])

history = model.fit(X, y, verbose=0, epochs=150)
plot_loss_accuracy(history)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# The decision boundary again passes from the middle of the data, but now we have much more misclassified points.

# %%
plot_decision_boundary(lambda x: model.predict(x), X, y)
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# The accuracy is 51%. **No matter where the model draws the linear line, it will misclassify half of the points, due to the nature of the dataset**.
#
# The confusion matrix we see here is an example one belonging to a poor classifier. Ideally we want confusion matrices like the ones we saw above. High numbers along the diagonals meaning that the classifier was right, and low numbers everywhere else where the classifier was wrong. In our visualization, the color blue represents the high numbers and yellow represents the low ones. So we would prefer to see blue on the diagonals and yellow everywhere else, blues everywhere is a bad sign meaning that our classifier is confused.

# %%
y_pred = model.predict(X, verbose=0)>0.5
print(classification_report(y, y_pred))
plot_confusion_matrix(model, X, y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.49      0.50       500
#            1       0.51      0.54      0.53       500
#
#     accuracy                           0.51      1000
#    macro avg       0.51      0.51      0.51      1000
# weighted avg       0.51      0.51      0.51      1000

# %% [markdown]
# ## Artificial Neural Networks (ANN)
# Now we will train a deep Artificial Neural Networks (ANN) to better classify the datasets which the logistic regression model struggled, Moons and Circles.

# %% [markdown]
# While building Keras models for logistic regression above, we performed the following steps:
#
# - Step 1: Define a Sequential model.
# - Step 2: Add a Dense layer with sigmoid activation function. This was the only layer we needed.
# - Step 3: Compile the model with an optimizer and loss function.
# - Step 4: Fit the model to the dataset.
# - Step 5: Analyze the results: plotting loss/accuracy curves, plotting the decision boundary, looking at the classification report, and understanding the confusion matrix.

# %% [markdown]
# While building a deep neural network, we only need to change step 2 such that, we will add several Dense layers one after another. The output of one layer becomes the input of the next. Keras again does most of the heavy lifting by initializing the weights and biases, and connecting the output of one layer to the input of the next. We only need to specify how many nodes we want in a given layer, and the activation function. It’s as simple as that.

# %%
X, y = make_moons(n_samples=1000, noise=0.05, random_state=0)

model = Sequential()
model.add(Dense(4, input_shape=(2,), activation='tanh')) #This layer has 4 neurons
model.add(Dense(2, activation='tanh')) #This layer has 2 neurons
model.add(Dense(1, activation='sigmoid'))

model.compile(Adam(learning_rate=0.01), 'binary_crossentropy', metrics=['accuracy'])

history = model.fit(X, y, verbose=1, epochs=100)

plot_loss_accuracy(history)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2600 - loss: 0.8159
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7440 - loss: 0.6371
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8830 - loss: 0.4774
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8730 - loss: 0.3584
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8780 - loss: 0.3118
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8770 - loss: 0.2944
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8810 - loss: 0.2873
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8830 - loss: 0.2830
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8840 - loss: 0.2773
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8830 - loss: 0.2788
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8860 - loss: 0.2711
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8870 - loss: 0.2683
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8860 - loss: 0.2654
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8900 - loss: 0.2635
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8870 - loss: 0.2556
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8900 - loss: 0.2507
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9000 - loss: 0.2384
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8980 - loss: 0.2262
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9160 - loss: 0.1938
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9350 - loss: 0.1592
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9590 - loss: 0.1201
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9750 - loss: 0.0887
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.0651
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9940 - loss: 0.0498
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9960 - loss: 0.0399
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0321
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0268
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0226
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0194
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0168
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0150
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0137
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0117
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0095
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.3899e-04
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.4963e-04
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.1373e-04
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.8680e-04
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.3688e-04
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.2652e-04
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.0082e-04
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.6238e-04
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.6518e-04
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.2385e-04
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.2492e-04
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.8227e-04
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.7899e-04
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.5029e-04
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.4804e-04
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.2879e-04
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.4018e-04
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.9136e-04
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.6624e-04
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.5650e-04
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.3129e-04
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.4145e-04

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 4)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 77 (312.00 B)
#  Trainable params: 25 (100.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 52 (212.00 B)

# %% [markdown]
# #### 📌 Parameter Calculation in Dense Layers
#
# For a Dense (fully connected) layer, the number of parameters is calculated as:
# $$
# Parameters = (inputs \times neurons) + neurons
# $$
#
# - `inputs × neurons` = weights
# - `neurons` = biases
#
#
#
#
# ## 📊 Applied to This Model
#
# **Layer 1 (Input: 2 → Neurons: 4):**
# \[
# (2 \times 4) + 4 = 12
# \]
#
# **Layer 2 (Input: 4 → Neurons: 2):**
# \[
# (4 \times 2) + 2 = 10
# \]
#
# **Layer 3 (Input: 2 → Neurons: 1):**
# \[
# (2 \times 1) + 1 = 3
# \]
#
#
#
# ## ✅ Total Trainable Parameters
#
# \[
# 12 + 10 + 3 = 25
# \]
#
#
#
# ## ⚠️ Note
#
# - **25** → Trainable model parameters
# - **52** → Optimizer parameters (Adam)
# - **77** → Total shown in summary
#
# Only the **trainable parameters (25)** are used during inference.

# %% [markdown]
# As you can see we first add a layer with 4 nodes and tanh activation function. Tanh is a commonly used activation function, and we'll learn more about it in another tutorial. We then add another layer with 2 nodes and again tanh activation. We finally add the last layer with 1 node and sigmoid activation. This is the final layer that we also used in the logistic regression model.
#
# This is not a very deep ANN, it only has 3 layers: input layer, 1 hidden layer, and the output layer. But notice a couple of patterns:
#
# Output layer still uses the sigmoid activation function since we're working on a binary classification problem.
# Non-output layers use the tanh activation function. If we added more hidden layers, they would also have tanh activation.
# We have fewer number of nodes in each subsequent layer. It's common to have less nodes as we stack layers on top of one another.
# We didn't build a very deep ANN here because it wasn't necessary. We already achieve perfect accuracy with this configuration.

# %% [markdown]
# The ANN is able to come up with a perfect separator to distinguish the classes.

# %%
plot_decision_boundary(lambda x: model.predict(x), X, y)
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# 100% precision, nothing misclassified.

# %%
y_pred = model.predict(X, verbose=0)>0.5
print(classification_report(y, y_pred))
plot_confusion_matrix(model, X, y)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       500
#            1       1.00      1.00      1.00       500
#
#     accuracy                           1.00      1000
#    macro avg       1.00      1.00      1.00      1000
# weighted avg       1.00      1.00      1.00      1000

# %% [markdown]
# ### Complex Data - Circles
#
# Now let's look at the Circles dataset, where the LR model achieved only 50% accuracy. The model is the same as above, we only change the input to the fit function. And we again achieve 100% accuracy.

# %%
X, y = make_circles(n_samples=1000, noise=0.05, factor=0.3, random_state=0)

model = Sequential()
model.add(Dense(4, input_shape=(2,), activation='tanh'))
model.add(Dense(2, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))

model.compile(Adam(learning_rate=0.01), 'binary_crossentropy', metrics=['accuracy'])

history = model.fit(X, y, verbose=0, epochs=50)

plot_loss_accuracy(history)

# %% [markdown]
# Similarly the decision boundary looks just like one we would draw by hand ourselves. The ANN was able to figure out an optimal separator.

# %%
plot_decision_boundary(lambda x: model.predict(x), X, y)
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Just like above we get 100% accuracy.

# %%
y_pred = model.predict(X, verbose=0)>0.5
print(classification_report(y, y_pred))
plot_confusion_matrix(model, X, y)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       500
#            1       1.00      1.00      1.00       500
#
#     accuracy                           1.00      1000
#    macro avg       1.00      1.00      1.00      1000
# weighted avg       1.00      1.00      1.00      1000
